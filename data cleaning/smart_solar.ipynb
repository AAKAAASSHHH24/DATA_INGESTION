# %%
import pandas as pd
HyperionSolar = pd.read_excel('./unclean_data/HyperionSolar.xlsx')

# %%
HyperionSolar
# Out:
#                                         Column1                      Column2  \
# 0                                  warranty for                        extra
# 1                                  linear power                       output
# 2                                    Solar Cell              MonoPERC 182 mm
# 3                                  No. of Cells                 144 (6 × 24)
# 4                                    Dimensions    2278±2 × 1134±2 × 30±1 mm
# 5                                        Weight                31.6 kg (±5%)
# 6                      Cable Cross Section Size         4mm2(IEC),12 AWG(UL)
# 7                                  Junction Box  IP68 rated (3 bypassdiodes)
# 8                           Max. System Voltage                     DC 1500V
# 9                         Operating Temperature                  -40℃ ~ +85℃
# 10                      Max. Fuse Rated Current                          30A
# ...
