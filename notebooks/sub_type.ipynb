# %%
import pandas as pd

# %%
prod = pd.read_excel('product_info.xlsx')
prod
# Out:
#        Variant SKU     Cost Model No. / MPN  \
# 0     USEC001-0133    12.00        M1080250
# 1     USEC001-0134    12.00        M1080249
# 2     USMI100-0049   200.00  NC0142-L-US-BQ
# 3     USMI100-0048   193.90  NC0142-US-BQ-A
# 4     USSP100-0175   271.40         XL-G11S
# ...            ...      ...             ...
# 2889  USSP100-0170   876.49     MPSL250-30D
# 2890  USSP100-0171  1148.35          RD2824
# 2891  USSP100-0172  1908.27       MS4448PAE
# 2892  USSP100-0173  1856.84       MS4024PAE
# 2893  USSP100-0174  1629.93   MS2012-20BL-U
#
#                                                   Title  \
# 0                      NEP M1080250 BQ Female Connector
# 1                        NEP M1080249 BQ Male Connector
# 2     NEP NC0142-L-US-BQ 580W Microinverter with Lan...
# 3     NEP NC0142-US-BQ-A 580W Microinverter with Por...
# 4            Q Cell, Q.PEAK DUO XL-G11S 590 Solar Panel
# ...                                                 ...
# ...

# %%
prod.isna().sum()
# Out:
# Variant SKU            0
# Cost                   0
# Model No. / MPN        0
# Title                  0
# Body (HTML)            0
# Product Type        2894
# Product Sub Type    2894
# dtype: int64

# %%
import pprint
pprint.pprint(prod['Body (HTML)'][0])
# Out:
# ('<p>Get the ultimate in electrical connectivity with the NEP M1080250 BQ '
#  'Female Connector. Crafted to meet the highest industry standards, this '
#  'robust connector ensures secure and reliable electrical connections in a '
#  'range of settings, from residential to industrial applications. Offering '
#  'both high performance and ease of use, the NEP BQ Female Connector is the '
#  'perfect choice for professionals and DIYers looking for quality and '
#  'reliability in their electrical systems.</p><h2>Features</h2><h3>Unmatched '
#  'Quality</h3><ul><li>Made of premium conductive materials to ensure '
#  'long-lasting performance.</li><li>Built to withstand tough conditions with a '
#  'corrosion-resistant finish.</li></ul><h3>Universal '
#  'Compatibility</h3><ul><li>Designed for broad use across multiple electrical '
#  'applications.</li><li>Meets industry-standard certifications for complete '
# ...

# %%
pip install beautifulsoup4
# Out:
# ...
#
#   Using cached beautifulsoup4-4.12.2-py3-none-any.whl (142 kB)
# ...
#   Obtaining dependency information for soupsieve>1.2 from https://files.pythonhosted.org/packages/4c/f3/038b302fdfbe3be7da016777069f26ceefe11a681055ea1f7817546508e3/soupsieve-2.5-py3-none-any.whl.metadata
# ...

# %%
from bs4 import BeautifulSoup

# %%
# Parse the HTML content
soup = BeautifulSoup(prod['Body (HTML)'][0], 'html.parser')

# Extract only the text
cleaned_text = soup.get_text()

print(cleaned_text)
# Out:
# Get the ultimate in electrical connectivity with the NEP M1080250 BQ Female Connector. Crafted to meet the highest industry standards, this robust connector ensures secure and reliable electrical connections in a range of settings, from residential to industrial applications. Offering both high performance and ease of use, the NEP BQ Female Connector is the perfect choice for professionals and DIYers looking for quality and reliability in their electrical systems.FeaturesUnmatched QualityMade of premium conductive materials to ensure long-lasting performance.Built to withstand tough conditions with a corrosion-resistant finish.Universal CompatibilityDesigned for broad use across multiple electrical applications.Meets industry-standard certifications for complete peace of mind.Effortless InstallationEngineered for easy, tool-free installation.Compatible with various wire types and sizes for maximum flexibility.SpecificationsGeneralModel: M1080250Type: Female ConnectorMaterial: Premium
# ...

# %%
prod['Body'] = None
for i in range(len(prod)):
    try:
        soup = BeautifulSoup(prod['Body (HTML)'][i], 'html.parser')
        # Extract only the text
        cleaned_text = soup.get_text()
        prod['Body'][i] = cleaned_text
    except Exception as e:
        prod['Body'][i] = prod['Body (HTML)'][i]

prod
# Out:
# C:\Users\Asus\AppData\Local\Temp\ipykernel_2620\2276666216.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   prod['Body'][i] = cleaned_text
# C:\Users\Asus\AppData\Local\Temp\ipykernel_2620\2276666216.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   prod['Body'][i] = cleaned_text
# C:\Users\Asus\AppData\Local\Temp\ipykernel_2620\2276666216.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# ...

# %%
criteria = pd.read_excel('criteria.xlsx')
criteria
# Out:
#           Product Type                Product Sub Type
# 0        Solar Modules                 Monocrystalline
# 1        Solar Modules                 Polycrystalline
# 2        Solar Modules                       Thin-Film
# 3        Solar Modules                        Bifacial
# 4        Solar Modules                 Flexible Panels
# 5            Inverters                String Inverters
# 6            Inverters                  Microinverters
# 7            Inverters               Central Inverters
# 8            Inverters                Hybrid Inverters
# 9            Inverters                  Snap Inverters
# 10   Storage Solutions             Lead-Acid Batteries
# 11   Storage Solutions           Lithium-Ion Batteries
# 12   Storage Solutions                  Flow Batteries
# 13   Storage Solutions             Saltwater Batteries
# 14  Charge Controllers                 PWM Controllers
# 15  Charge Controllers                MPPT Controllers
# ...

# %%
Product_Types = list(criteria['Product Type'].unique())
Product_SubTypes = list(criteria['Product Sub Type'].unique())

# %%
##  Some necessary imports ..
import os, openai
import numpy as np
import pandas as pd

from langchain.document_loaders import DirectoryLoader
from langchain.document_loaders import DirectoryLoader
from langchain.text_splitter import RecursiveCharacterTextSplitter
from langchain.embeddings.openai import OpenAIEmbeddings
from langchain.llms import OpenAI
from langchain.chains.question_answering import load_qa_chain

from langchain.document_loaders import PyPDFLoader
from langchain.vectorstores import Chroma

from langchain.chat_models import ChatOpenAI
from langchain.chains.question_answering import load_qa_chain
from langchain.chains import RetrievalQA

from langchain.output_parsers import CommaSeparatedListOutputParser
from langchain.prompts import PromptTemplate, ChatPromptTemplate, HumanMessagePromptTemplate
from langchain.llms import OpenAI
from langchain.chat_models import ChatOpenAI

from langchain.document_loaders import PyPDFLoader
from langchain.document_loaders import WikipediaLoader
from langchain.retrievers import WikipediaRetriever
from langchain.document_loaders import DirectoryLoader
from langchain.document_loaders import UnstructuredHTMLLoader
from langchain.document_loaders import BSHTMLLoader
from langchain.document_loaders import TextLoader

from langchain.chains import RetrievalQA
from langchain.document_loaders import TextLoader
from langchain.embeddings.openai import OpenAIEmbeddings
from langchain.llms import OpenAI
from langchain.text_splitter import CharacterTextSplitter
from langchain.vectorstores import Chroma
from langchain.chains.router import MultiRetrievalQAChain

# %%
from dotenv import find_dotenv, load_dotenv

# %%
os.environ["OPENAI_API_KEY"] = "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"

# %%
from langchain.output_parsers import StructuredOutputParser, ResponseSchema
from langchain.prompts import PromptTemplate, ChatPromptTemplate, HumanMessagePromptTemplate
from langchain.llms import OpenAI
from langchain.chat_models import ChatOpenAI
from typing import List

from langchain.llms import OpenAI
from langchain.output_parsers import PydanticOutputParser
from langchain.prompts import PromptTemplate
from langchain.pydantic_v1 import BaseModel, Field, validator
from langchain.chat_models import ChatOpenAI

# %%
model_name = "gpt-3.5-turbo"
temperature = 0.0
model = OpenAI(model_name=model_name, temperature=temperature)

# %%
# Define your desired data structure.
class ProductType(BaseModel):
    Product_Type : str = Field(description="Product Type of this Product")
    Product_Sub_Type : str = Field(description="Product Sub Type of this Product")  

# Set up a parser + inject instructions into the prompt template.
parser = PydanticOutputParser(pydantic_object=ProductType)

# %%
prompt_level1 = PromptTemplate(
    template="""
        Consider yourself an expert in analysing SOLAR POWER PRODUCTS:
        \n{format_instructions} 
        You are given the Title of the product as  the following: {title}.
        You are given the description body of the same product as the following: {body}
        For generating Product_Type select from the following list: {Product_Types}.
        For generating Product_Sub_Type select from the following list: {Product_SubTypes}.
        Only include the generated answer in your response and nothing else""",
    input_variables=["title","body","Product_Types","Product_SubTypes"],
    partial_variables={"format_instructions": parser.get_format_instructions()},
)

# %%
_input = prompt_level1.format_prompt(title= prod['Title'][0] , body = prod['Body'][0] , Product_Types = Product_Types, Product_SubTypes = Product_SubTypes )

output_level1 = model(_input.to_string())

pprint.pprint(output_level1)
# Out:
# '{"Product_Type": "Solar Modules", "Product_Sub_Type": "Monocrystalline"}'

# %%
_input = prompt_level1.format_prompt(title= prod['Title'][1] , body = prod['Body'][1] , Product_Types = Product_Types, Product_SubTypes = Product_SubTypes )

output_level1 = model(_input.to_string())

pprint.pprint(output_level1)
# Out:
# '{"Product_Type": "Solar Modules", "Product_Sub_Type": "Monocrystalline"}'

# %%
_input = prompt_level1.format_prompt(title= prod['Title'][2] , body = prod['Body'][2] , Product_Types = Product_Types, Product_SubTypes = Product_SubTypes )

output_level1 = model(_input.to_string())

pprint.pprint(output_level1)
# Out:
# '{"Product_Type": "Inverters", "Product_Sub_Type": "Microinverters"}'

# %%
_input = prompt_level1.format_prompt(title= prod['Title'][3] , body = prod['Body'][3] , Product_Types = Product_Types, Product_SubTypes = Product_SubTypes )

output_level1 = model(_input.to_string())

pprint.pprint(output_level1)
# Out:
# '{"Product_Type": "Inverters", "Product_Sub_Type": "Microinverters"}'

# %%
_input = prompt_level1.format_prompt(title= prod['Title'][4] , body = prod['Body'][4] , Product_Types = Product_Types, Product_SubTypes = Product_SubTypes )

output_level1 = model(_input.to_string())

pprint.pprint(output_level1)
# Out:
# ('{\n'
#  '  "Product_Type": "Solar Modules",\n'
#  '  "Product_Sub_Type": "Monocrystalline"\n'
#  '}')

# %%
_input = prompt_level1.format_prompt(title= prod['Title'][5] , body = prod['Body'][5] , Product_Types = Product_Types, Product_SubTypes = Product_SubTypes )

output_level1 = model(_input.to_string())

pprint.pprint(output_level1)
# Out:
# '{"Product_Type": "Solar Modules", "Product_Sub_Type": "Monocrystalline"}'

# %%
import ast

# %%
for i in range(len(prod)):
    _input = prompt_level1.format_prompt(title= prod['Title'][i] , body = prod['Body'][i] , Product_Types = Product_Types, Product_SubTypes = Product_SubTypes )
    output_level1 = model(_input.to_string())
    output = ast.literal_eval(output_level1)
    prod['Product Type'][i] = output['Product_Type']
    prod['Product Sub Type'][i] = output['Product_Sub_Type']
# Out:
# C:\Users\Asus\AppData\Local\Temp\ipykernel_2620\1056879469.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   prod['Product Type'][i] = output['Product_Type']
# C:\Users\Asus\AppData\Local\Temp\ipykernel_2620\1056879469.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   prod['Product Sub Type'][i] = output['Product_Sub_Type']
# Retrying langchain.llms.openai.completion_with_retry.<locals>._completion_with_retry in 4.0 seconds as it raised Timeout: Request timed out: HTTPSConnectionPool(host='api.openai.com', port=443): Read timed out. (read timeout=600).
# ...

# %%
prod.to_excel('Output.xlsx')

# %%
import pandas as pd
out = pd.read_excel('Output.xlsx')
out
# Out:
#       Unnamed: 0   Variant SKU     Cost Model No. / MPN  \
# 0              0  USEC001-0133    12.00        M1080250
# 1              1  USEC001-0134    12.00        M1080249
# 2              2  USMI100-0049   200.00  NC0142-L-US-BQ
# 3              3  USMI100-0048   193.90  NC0142-US-BQ-A
# 4              4  USSP100-0175   271.40         XL-G11S
# ...          ...           ...      ...             ...
# 2889        2889  USSP100-0170   876.49     MPSL250-30D
# 2890        2890  USSP100-0171  1148.35          RD2824
# 2891        2891  USSP100-0172  1908.27       MS4448PAE
# 2892        2892  USSP100-0173  1856.84       MS4024PAE
# 2893        2893  USSP100-0174  1629.93   MS2012-20BL-U
#
#                                                   Title  \
# 0                      NEP M1080250 BQ Female Connector
# 1                        NEP M1080249 BQ Male Connector
# 2     NEP NC0142-L-US-BQ 580W Microinverter with Lan...
# 3     NEP NC0142-US-BQ-A 580W Microinverter with Por...
# ...

# %%
out['Product Type'].unique()
# Out:
# array(['Solar Modules', 'Inverters', 'Wiring & Cables',
#        'Solar Equipments', 'Racking', 'Breakers', 'Fuses',
#        'Connectors & Junctions', 'Storage Solutions',
#        'Charge Controllers', 'Inverter', 'Safety & Maintenance Equipment',
#        'Roof Mounts', 'DC Power Supply', 'Surge Protection Devices',
#        'Surge Arrestor', 'Surge Protectors', 'Surge Protector Device',
#        'Current Transformer', 'Rapid Shutdown Unit', 'Disconnect',
#        'Monitoring systems', 'Shunt', 'Disconnects',
#        'Inverter Accessories', 'Flashing', 'Generators',
#        'Standby Generators', 'Standby Generator', 'Transfer Switch',
#        'Current Transformers', 'Surge Protection'], dtype=object)

# %%
out['Product Sub Type'].unique()
# Out:
# array(['Monocrystalline', 'Microinverters', 'PV Wire',
#        'PV Photovoltaic Wire', 'Wiring & Cables', 'Racking Accessories',
#        'Roof Mounts', 'Clamps', 'Connectors & Junctions',
#        'Universal Clamps', 'Labels', 'Plug-in Circuit Breakers',
#        'Combiner & Junction Boxes', 'TD Fuses', 'Disconnects',
#        'Crimping Tool', 'Rail Splice', 'MC4 Connector',
#        'Lithium-Ion Batteries', 'Bifacial', 'Inverter Accessories',
#        'String Inverters', 'Central Inverters', 'Monitoring systems',
#        'Hybrid Inverters', 'Rapid Shutdown Kit', 'Inverters',
#        'CT (Current Transformer)', 'CT-SPL-225A-T-01', 'Backup Interface',
#        'Grid Capable / EV Charging Inverter', 'Optimizers',
#        'PWM Controllers', 'Transfer Switch', 'Pure Sine Wave',
#        'Optional Remote Control Programmable', 'Racking',
#        'Battery Monitors', 'Fuses', 'ANL Fuses', 'Safety Switch',
#        'Energy Storage System', 'Snap Inverters',
# ...
